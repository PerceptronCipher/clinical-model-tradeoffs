# %% [markdown]
# # Section 3: model comparison

# %% [markdown]
# ## Model Comparison: Understanding Tradeoffs in Clinical Prediction
#
# This notebook evaluates multiple machine learning models on a standardized clinical dataset. The goal is not only to compare performance but to understand the **tradeoffs** each model makes in terms of accuracy, interpretability, and computational behavior.

# %%
# import libraries
import numpy as np
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, cross_val_score

# %% [markdown]
# ## Load Preprocessed Dataset
#
# We reuse the preprocessed dataset generated in the previous notebook to ensure consistent experimental conditions across all models.
